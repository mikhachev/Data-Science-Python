# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

pd.options.display.max_columns = 100
# %matplotlib inline

# %%
data = pd.read_csv('input/train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %%
data.loc[data['Shops_2'] == 'A', :].count()
# Out:
# Id               825
# DistrictId       825
# Rooms            825
# Square           825
# LifeSquare       548
# KitchenSquare    825
# Floor            825
# HouseFloor       825
# HouseYear        825
# Ecology_1        825
# Ecology_2        825
# Ecology_3        825
# Social_1         825
# Social_2         825
# Social_3         825
# Healthcare_1     154
# Helthcare_2      825
# Shops_1          825
# Shops_2          825
# Price            825
# dtype: int64

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %% [markdown]
# #### train_test_split

# %%
train, valid = train_test_split(data, test_size=0.3, random_state=42)

# %%
train.head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9069  14604          23    1.0   41.681380   22.796166            8.0     14
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 7738    235          87    1.0   39.710131   19.538663            8.0      4
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5058  10773          77    3.0   79.195825   44.421062           10.0     16
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9069        17.0       2015   0.075779         B         B         6
# 2603         3.0       1977   0.014073         B         B         2
# 7738        17.0       1986   0.100456         B         B        43
# 1579         1.0       2017   0.041125         B         B        46
# 5058        17.0       1984   0.298205         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9069      1437         3           NaN            0        2       B
# 2603       475         0           NaN            0        0       B
# 7738      7227         0           NaN            1        6       A
# 1579      9515         5           NaN            1       10       B
# 5058      4048         3           NaN            1        3       B
#
#               Price
# 9069   88504.384965
# 2603  207007.956663
# 7738  182126.280899
# 1579  524365.550705
# 5058  322048.433990

# %%
mean_cost_all=sum_price_all/sq_price_all
mean_cost_all
# Out:
# 3812.6892373195114

# %%
plt.scatter(train['Square'], train['Price']/train['Square'])
plt.axis([0, 200,0,30000])
plt.xlabel('Площадь')
plt.ylabel('Цена М2')
plt.show()

# %%
plt.scatter(train['Square'], train['Price']/train['Square'])
plt.axis([0, 200,0,30000])
plt.xlabel('Площадь')
plt.ylabel('Цена М2')
plt.show()

# %%
train.loc[train['HouseYear'] > 2020, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4189         9.0       4968   0.319809         B         B        25
# 1497        12.0   20052011   0.136330         B         B        30
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4189      4756        16        2857.0            5        8       B
# 1497      6141        10         262.0            3        6       B
#
#               Price
# 4189  243028.603096
# 1497  254084.534396

# %%
# А ведь с полным датафреймом будет точнее
mean_year = np.round(data.loc[(data['HouseYear']<= 2020) & (data['HouseYear']>= 1813) , 'HouseYear'].mean())
mean_year
# Out:
# 1985.0

# %%
train.loc[train['HouseYear'] < 1917, :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2656  14556         183    4.0  151.150660   98.187482           23.0      6
# 7611   7920         183    3.0  102.964468   48.322107           14.0      4
# 910    6751         172    2.0   56.172364   28.384213            7.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2656         7.0       1912   0.037316         B         B        32
# 7611         6.0       1916   0.037316         B         B        32
# 910          6.0       1914   0.000000         B         B         7
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2656      6748        93         562.0            4       10       B
# 7611      6748        93         562.0            4       10       B
# 910       1660        39        1786.0            1        5       B
#
#               Price
# 2656  284884.959104
# 7611  284608.939261
# 910   423580.477982

# %%
       
train.loc[train['KitchenSquare'] <5 , :].head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5753   3766          62    3.0  127.417560         NaN            0.0      9
# 477    8849          45    1.0   63.419553    2.286357            1.0      3
# 9642  16202         105    1.0   22.072457   16.540036            2.0      4
# 1777  15980           1    1.0   42.106365   41.782263            1.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1579         1.0       2017   0.041125         B         B        46
# 5753         0.0       1977   0.072158         B         B         2
# 477          1.0       1977   0.195781         B         B        23
# 9642         9.0       1963   0.069660         B         B        31
# 1777         1.0       2019   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1579      9515         5           NaN            1       10       B
# 5753       629         1           NaN            0        0       A
# 477       5212         6           NaN            3        2       B
# 9642      6119         4           NaN            1        2       B
# 1777       264         0           NaN            0        1       B
#
#               Price
# 1579  524365.550705
# 5753  282877.332154
# 477   325600.765809
# 9642  126778.794309
# 1777  138632.726757

# %%
train.loc[train['KitchenSquare'] >50 , :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 8584  14679          81    1.0   32.276663   19.278394         1970.0      6
# 227   16395           2    3.0   79.722243   44.731219           72.0     12
# 4651  12552          58    3.0  116.405693  113.109653          112.0      3
# 5162  11739          27    2.0   61.070298   59.845092           58.0      8
# 9889  12918          23    2.0   51.440463   53.134243           51.0      3
# 2916  12390          72    3.0   97.490674   99.323558           96.0     22
# 1064  14656          62    1.0   47.100719   46.447960         2014.0      4
# 5888  16593          52    2.0   64.859242         NaN           62.0     15
# 5904    673          27    1.0   54.418214   51.498581           51.0     10
# 1455  12507          54    2.0   79.810535   79.578961           78.0     10
# 9895   2737          27    3.0  123.430072  125.806981          123.0      5
# 5149  13703          42    1.0   38.071692   19.723548           73.0      9
# 7088   6569          27    1.0   38.220258   18.716856           84.0      4
# 6036  12666          34    2.0   60.603363    2.400832           58.0     14
# 2969   7441          62    3.0  114.734473  112.589083          112.0      3
# 8232   7162          34    2.0   56.738764   57.510395           54.0     26
# 4079   6508          23    2.0   67.146049   33.959154           63.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8584         1.0       1977   0.006076         B         B        30
# 227         16.0       1987   0.130618         B         B        39
# 4651         3.0       2016   0.437885         B         B        23
# 5162        17.0       2016   0.072158         B         B         2
# 9889        17.0       2017   0.005767         B         B         1
# 2916        25.0       2019   0.210473         B         B        11
# 1064         1.0       2014   0.072158         B         B         2
# 5888        17.0       1977   0.371149         B         B        34
# 5904        17.0       2017   0.072158         B         B         2
# 1455        15.0       2014   0.006076         B         B        30
# 9895        10.0       2015   0.017647         B         B         2
# 5149        10.0       2006   0.158249         B         B        21
# 7088        17.0       2018   0.011654         B         B         4
# 6036        22.0       1977   0.069753         B         B        53
# 2969         3.0       2015   0.072158         B         B         2
# 8232        25.0       2016   0.069753         B         B        53
# 4079        17.0       2019   0.034656         B         B         0
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8584      5285         0         645.0            6        6       B
# 227      10418         9         900.0            1        9       B
# 4651      5735         3        1084.0            0        5       B
# 5162       629         1           NaN            0        0       A
# 9889       388         0           NaN            0        0       B
# 2916      2398         2        1994.0            3        0       B
# 1064       629         1           NaN            0        0       A
# 5888      7065         1         750.0            2        5       B
# 5904       629         1           NaN            0        0       A
# 1455      5285         0         645.0            6        6       B
# 9895       469         0           NaN            0        0       B
# 5149      5731         0           NaN            1        0       B
# 7088       915         0           NaN            0        0       B
# 6036     13670         4           NaN            1       11       B
# 2969       629         1           NaN            0        0       A
# 8232     13670         4           NaN            1       11       B
# 4079       168         0           NaN            0        0       B
#
#               Price
# 8584  105539.556275
# 227   370148.625285
# 4651  296165.936689
# 5162  212188.959537
# 9889   88150.012510
# 2916  445074.956552
# 1064  108337.484207
# 5888  185993.474671
# 5904  133273.635012
# 1455  438708.707579
# 9895  234194.837047
# 5149  160488.033165
# 7088   99079.960518
# 6036  261733.472106
# 2969  315245.521059
# 8232  244220.621495
# 4079  193130.585871

# %%
train.loc[train['Square'] >170 , :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9910  16568          27    4.0  200.334539  201.627361           25.0      1
# 4262     28           9    2.0  604.705972         NaN            1.0     17
# 652    3718          56    3.0  190.857689  107.376164           19.0      7
# 4487  13434          13    5.0  183.382273  100.985505           15.0      2
# 4690   2307         102    1.0  409.425181  410.639749           10.0      4
# 7084   5376          93    2.0  170.379494         NaN            1.0      3
# 1641  11055         151    1.0  174.649522  174.837082           15.0     10
# 5087  15947         129    4.0  185.906396   84.830074           31.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9910         2.0       2013   0.041116         B         B        53
# 4262        18.0       1977   0.161532         B         B        25
# 652          3.0       2007   0.000000         B         B        23
# 4487         6.0       1997   0.090799         B         B        74
# 4690         4.0       2016   0.238617         B         B        26
# 7084         2.0       1977   0.004949         B         B         0
# 1641        12.0       1958   0.236108         B         B        16
# 5087         3.0       2015   0.020741         B         B        24
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9910     14892         4           NaN            1        4       B
# 4262      5648         1          30.0            2        4       B
# 652       5067         4           NaN            2        6       B
# 4487     19083         2           NaN            5       15       B
# 4690      3889         6         705.0            3        6       B
# 7084       186         0           NaN            0        0       B
# 1641      3893        27           NaN            3       10       B
# 5087      5613         5        1340.0            2        5       B
#
#               Price
# 9910  528560.506016
# 4262  187717.242538
# 652   338644.075979
# 4487  622888.825328
# 4690   90470.430830
# 7084  194582.912756
# 1641  232766.187698
# 5087  340273.238253

# %%
train.loc[train['Square'] <10.0 , :]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 3413   9487           5    1.0  5.129222    5.549458            1.0      1
# 3280  10527          27    1.0  4.380726   40.805837            1.0     10
# 8030  13265           1    3.0  4.823679   79.767964            0.0      6
# 9613   7657          38    1.0  4.502784    4.618547            1.0     28
# 1316  11526          27    1.0  4.633498    1.969969            1.0     18
# 4853   3224          27    0.0  2.377248    0.873147            0.0      1
# 9294   6782          45    1.0  2.954309    5.257278            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3413         1.0       1977   0.150818         B         B        16
# 3280        17.0       2013   0.211401         B         B         9
# 8030        17.0       1977   0.007122         B         B         1
# 9613         1.0       1977   0.060753         B         B        15
# 1316         1.0       1977   0.011654         B         B         4
# 4853         0.0       1977   0.017647         B         B         2
# 9294         1.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 3413      3433         4        2643.0            4        5       B
# 3280      1892         0           NaN            0        1       B
# 8030       264         0           NaN            0        1       B
# 9613      2787         2         520.0            0        7       B
# 1316       915         0           NaN            0        0       B
# 4853       469         0           NaN            0        0       B
# 9294      5212         6           NaN            3        2       B
#
#               Price
# 3413  369472.403061
# 3280   97560.720383
# 8030  237716.681261
# 9613  483283.488083
# 1316  107604.269441
# 4853  126596.941798
# 9294  438005.182323

# %%
train.loc[train['Id']==11607, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 4189  243028.603096

# %%
train.loc[train['Rooms']<1, :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4366         0.0       1977   0.243205         B         B         5
# 1397         3.0       2016   0.075424         B         B        11
# 2269         0.0       1977   0.211401         B         B         9
# 3911         0.0       2015   0.118537         B         B        30
# 4853         0.0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4366      1564         0         540.0            0        0       B
# 1397      3097         0           NaN            0        0       B
# 2269      1892         0           NaN            0        1       B
# 3911      6207         1        1183.0            1        0       B
# 4853       469         0           NaN            0        0       B
#
#               Price
# 4366  212864.799112
# 1397  268394.744389
# 2269   98129.976788
# 3911  217009.338463
# 4853  126596.941798

# %%
train.loc[train['Rooms']>5, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1454        17.0       2014   0.007122         B         B         1
# 2170         9.0       1969   0.033494         B         B        66
# 377         22.0       2002   0.090799         B         B        74
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1454       264         0           NaN            0        1       B
# 2170     10573         1        1322.0            3        8       B
# 377      19083         2           NaN            5       15       B
#
#               Price
# 1454   78364.616704
# 2170  229661.964416
# 377   317265.323792

# %%
train.loc[train['Square']>200, :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9910  16568          27    4.0  200.334539  201.627361           25.0      1
# 4262     28           9    2.0  604.705972         NaN            1.0     17
# 4690   2307         102    1.0  409.425181  410.639749           10.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9910         2.0       2013   0.041116         B         B        53
# 4262        18.0       1977   0.161532         B         B        25
# 4690         4.0       2016   0.238617         B         B        26
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9910     14892         4           NaN            1        4       B
# 4262      5648         1          30.0            2        4       B
# 4690      3889         6         705.0            3        6       B
#
#               Price
# 9910  528560.506016
# 4262  187717.242538
# 4690   90470.430830

# %%
train.loc[train['LifeSquare']>200, :]
# Out:
#          Id  DistrictId  Rooms      Square   LifeSquare  KitchenSquare  Floor  \
# 9910  16568          27    4.0  200.334539   201.627361           25.0      1
# 4328  16550          27    3.0   81.694417  7480.592129            1.0      9
# 8437  15886          85    3.0   78.059331   461.463614           10.0     12
# 4690   2307         102    1.0  409.425181   410.639749           10.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9910         2.0       2013   0.041116         B         B        53
# 4328        17.0       2016   0.017647         B         B         2
# 8437        16.0       1998   0.037178         B         B        52
# 4690         4.0       2016   0.238617         B         B        26
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9910     14892         4           NaN            1        4       B
# 4328       469         0           NaN            0        0       B
# 8437     11217         1        2300.0            1        7       B
# 4690      3889         6         705.0            3        6       B
#
#               Price
# 9910  528560.506016
# 4328  217357.492366
# 8437  394253.299978
# 4690   90470.430830

# %%
train.loc[train['HouseFloor']>40, :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 8854     78          30    2.0   65.773749   66.811789            1.0      8
# 6131  10806           5    1.0   51.944587   48.709601            1.0      6
# 4323   6589          30    1.0   62.110823   52.812128            4.0     31
# 2781   1674          76    2.0   74.344672   41.044132            5.0     42
# 8599   9300          74    2.0   71.747869   74.579809            9.0      5
# 3974   6502          20    1.0  126.389517  103.637322           14.0     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8854       117.0       1977   0.000078         B         B        22
# 6131        99.0       1977   0.150818         B         B        16
# 4323        44.0       2009   0.000078         B         B        22
# 2781        48.0       2016   0.000000         B         B         7
# 8599        99.0       1977   0.075779         B         B         6
# 3974        47.0       2012   0.019509         B         B        37
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8854      6398       141        1046.0            3       23       B
# 6131      3433         4        2643.0            4        5       B
# 4323      6398       141        1046.0            3       23       B
# 2781      1660        39        1786.0            1        5       B
# 8599      1437         3           NaN            0        2       B
# 3974      7687        11         176.0            5        5       B
#
#               Price
# 8854  207248.370520
# 6131  296127.115515
# 4323  117647.461002
# 2781  411691.504766
# 8599  243329.912579
# 3974  450706.552655

# %%
#Средняя цена метра на 1 этаже
train.loc[train['Floor'] == 1, 'Price'].sum()/train.loc[train['Floor'] == 1, 'Square'].sum()
# Out:
# 3452.9511180000104

# %%
#Средняя цена метра на остальных этажах
#train.loc[(train['Floor'] > 1) & (train['Floor'] ==train['HouseFloor']), 'Price'].sum()/train.loc[(train['Floor'] > 1)& (train['Floor'] ==train['HouseFloor']), 'Square'].sum()
train.loc[(train['Floor'] > 1) , 'Price'].sum()/train.loc[(train['Floor'] > 1), 'Square'].sum()
# Out:
# 3816.2027121038022

# %%
train.loc[train['Floor'] > train['HouseFloor'], :].head(20)
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5753   3766          62    3.0  127.417560         NaN            0.0      9
# 3548  11463         129    3.0   72.953912   39.478723            9.0     16
# 2726   9347          27    1.0   46.513651   21.032802           14.0      7
# 477    8849          45    1.0   63.419553    2.286357            1.0      3
# 1777  15980           1    1.0   42.106365   41.782263            1.0     15
# 468   12189          28    3.0   76.205998   46.656823           10.0     18
# 5368  15597         169    2.0   68.896696    5.336872            1.0     11
# 3881  13291          44    2.0   48.003717   32.700670            5.0      7
# 8353  13552          62    2.0   71.567578         NaN            0.0      7
# 7812   6108         168    2.0   60.405000   32.474066            9.0      6
# 2569   6837         165    1.0   40.781752   19.251596            0.0      9
# 7359   8899          27    2.0   60.085225         NaN            1.0     16
# 1989    131           1    1.0   42.808105         NaN            1.0     18
# 6973   9412          23    1.0   33.346258         NaN            1.0      5
# 1410   1843          74    1.0   49.635712    3.411048            1.0      4
# 2404   3846          55    3.0   86.383613   51.123106            8.0      7
# 5397   6784          61    3.0   80.404067   47.944369           10.0     19
# 5030   2656          27    1.0   41.698016   21.265494            1.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2603         3.0       1977   0.014073         B         B         2
# 1579         1.0       2017   0.041125         B         B        46
# 5753         0.0       1977   0.072158         B         B         2
# 3548        15.0       1991   0.460556         B         B        20
# 2726         6.0       1977   0.075424         B         B        11
# 477          1.0       1977   0.195781         B         B        23
# 1777         1.0       2019   0.007122         B         B         1
# 468         17.0       2000   0.333892         B         B        30
# 5368         1.0       2016   0.178917         B         B        18
# 3881         5.0       1961   0.036122         B         B        24
# 8353         0.0       1977   0.072158         B         B         2
# 7812         5.0       1990   0.341072         B         B        27
# 2569         0.0       1977   0.020741         B         B        24
# 7359        15.0       1977   0.211401         B         B         9
# 1989        17.0       1977   0.007122         B         B         1
# 6973         1.0       1977   0.034656         B         B         0
# 1410         1.0       1977   0.309479         B         B        35
# 2404         6.0       2000   0.041365         B         B        31
# 5397        17.0       1989   0.300323         B         B        52
# 5030         1.0       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2603       475         0           NaN            0        0       B
# 1579      9515         5           NaN            1       10       B
# 5753       629         1           NaN            0        0       A
# 3548      4386        14           NaN            1        5       B
# 2726      3097         0           NaN            0        0       B
# 477       5212         6           NaN            3        2       B
# 1777       264         0           NaN            0        1       B
# 468       6564         1           NaN            0        0       B
# 5368      3594         4         192.0            1        5       B
# 3881      4378         0        1036.0            1        1       B
# 8353       629         1           NaN            0        0       A
# 7812      5664        48        2300.0            3       11       B
# 2569      5613         5        1340.0            2        5       B
# 7359      1892         0           NaN            0        1       B
# 1989       264         0           NaN            0        1       B
# 6973       168         0           NaN            0        0       B
# 1410      7715         4         990.0            0        6       B
# 2404      5569         0           NaN            1        4       B
# 5397     10311         6           NaN            1        9       B
# 5030       469         0           NaN            0        0       B
#
#               Price
# 2603  207007.956663
# 1579  524365.550705
# 5753  282877.332154
# 3548  358129.914474
# 2726  124345.245905
# 477   325600.765809
# 1777  138632.726757
# 468   361460.801718
# 5368  338780.798345
# 3881  180646.782352
# 8353  159659.160189
# 7812  301088.955660
# 2569  131026.307065
# 7359  137285.697444
# 1989  135805.181590
# 6973   65334.292569
# 1410  146838.036852
# 2404  311644.492268
# 5397  358747.777778
# 5030  139819.678585

# %%
#Средняя цена метра на остальных этажах
train.loc[train['Floor'] ==train['HouseFloor'], 'Price'].sum()/train.loc[train['Floor'] ==train['HouseFloor'], 'Square'].sum()
# Out:
# 3819.5594178252795

# %%
train.loc[train['Floor'] >1 , 'Price'].mean()
# Out:
# 215203.87113497863

# %%
mean_price = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price']].mean().\
    rename(columns={'Price':'mean_price'})
mean_price.head()
# Out:
#    DistrictId  Rooms     mean_price
# 0           0    1.0  145789.889600
# 1           0    2.0  198451.332808
# 2           0    3.0  291670.749162
# 3           1    1.0  147116.367405
# 4           1    2.0  198775.648383

# %%
train.loc[(train['Square']<train['LifeSquare']+train['KitchenSquare']) & (train['Square']< 40), :].head()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4060  12217          23    1.0  35.770587   35.287517            1.0      7
# 3495  12863          27    1.0  36.181445   38.075191            0.0      2
# 6041  13875          20    1.0  28.438794   32.514021            6.0      6
# 495   10071          27    2.0  34.665783   36.079447            9.0      3
# 7360  12141          53    1.0  38.156315   38.957149            1.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4060         9.0       2016   0.034656         B         B         0
# 3495        12.0       1977   0.011654         B         B         4
# 6041        10.0       2014   0.019509         B         B        37
# 495         12.0       2016   0.072158         B         B         2
# 7360        19.0       2017   0.049637         B         B        34
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4060       168         0           NaN            0        0       B
# 3495       915         0           NaN            0        0       B
# 6041      7687        11         176.0            5        5       B
# 495        629         1           NaN            0        0       A
# 7360      7759         0         229.0            1        3       B
#
#               Price
# 4060   72962.598347
# 3495   88623.960046
# 6041  199248.114376
# 495   103182.855154
# 7360  242866.633362

# %%
# Здесь вычистим случаи, не являющиеся массовыми, только для тренировочной выборки 
train.loc[train['Id']==12638, ['Rooms']] = 4.0   
train.loc[train['Id']==8491, ['Rooms']] = 1.0
train.loc[train['Id']==11607, ['HouseYear']] = 1968
train.loc[train['Id']==10814, ['HouseYear']] = 2011
train.loc[train['Id']==492, ['Square']] = 60.4
train.loc[train['Id']==492, ['LifeSquare']] = 48.2
train.loc[train['Id']==2825, ['Square']] = 40.9
train.loc[train['Id']==2825, ['LifeSquare']] = 25.2
train.loc[train['Id']==14679, ['KitchenSquare']] = 8.0
train.loc[train['Id']==14656, ['KitchenSquare']] = 10.0
train.loc[train['Id']==16550, ['LifeSquare']] = 74.8 
train.loc[train['Id']==15886, ['LifeSquare']] = 46.2 
train.loc[train['Id']==13875, ['Square']] = 32.8
train.loc[train['Id']==13265, ['Square']] = 88.8
train.loc[train['Id']==13875, ['LifeSquare']] = 28.2 
train.loc[train['Id']==9487, ['Square']] = 17.0
train.loc[train['Id']==1748, ['Square']] = 70.0
train.loc[train['Id']==11526, ['Square']] = 46.0
train.loc[train['Id']==15127, ['Square']] = 30.0
train.loc[train['Id']==15744, ['Square']] = 98.0
train.loc[train['Id']==7657, ['Square']] = 60.0
train.loc[train['Id']==6782, ['Square']] = 57.0

# %%
def clean_rooms(df):
    df.loc[(df['Rooms']==0), ['Rooms']] = 1.0
    df.loc[(df['Rooms']>3)&(df['Square']<45) , ['Rooms']] = 1.0
    df.loc[(df['Rooms']>4)&(df['Square']<65)&(df['Square']>=47) , ['Rooms']] = 2.0
    df.loc[(df['Rooms']>5)&(df['Square']<80)&(df['Square']>=65) , ['Rooms']] = 3.0
    df.loc[(df['Rooms']>5)&(df['Square']/df['Rooms']<20) , ['Rooms']] = np.round(df['Square']/df['Rooms'])

# %%
def clean_kitchen(df):
    
    df.loc[df['KitchenSquare'] >50 , ['KitchenSquare']] = df['Square'] - df['LifeSquare']-5
    df.loc[(df['KitchenSquare'] >df['Square']*0.5) & (df['Square'] >18), ['KitchenSquare']] =  9.0
    # По СанПин площадь кухни не меньше 5кв.м.
    df.loc[(df['KitchenSquare'] < 5.0) & (df['KitchenSquare'] != 0.0) , ['KitchenSquare']] = 9.0

# %%
def clean_year(df,  mean_year=mean_year):
    # Идея: вычислять год средний в районе.
    df.loc[df['HouseYear'] > 2020, 'HouseYear'] = mean_year
    df.loc[df['HouseYear'] < 1813, 'HouseYear'] = mean_year

# %%
def clean_life_square(df):
    df.loc[(df['LifeSquare'].isnull()), 'LifeSquare'] = df['Square']*0.6
    df.loc[(df['LifeSquare'] > 400)&(df['LifeSquare'] > df['Square']), 'LifeSquare'] = df['Square']*0.8

# %%
#Сделал 2 этапа подготовки жилой площади, иначе могут возникнуть новые некорректные данные
def prepare_life_square(df):
    # вычистим случай, когда есть реалистинчый lifesquare, но маленькая площадь
    #df.loc[(df['LifeSquare'] > df['Square']*7)&(df['Square']<18)&(df['m2_cost']>12000), 'Square'] = df['LifeSquare']+5
    df.loc[(df['LifeSquare'] > df['Square']*7)&(df['Square']<18), 'Square'] = df['LifeSquare']+10
    
    df.loc[((df['LifeSquare'] < 5) | (df['LifeSquare'] > df['Square']))&(df['KitchenSquare']>4)&(df['KitchenSquare']<df['Square']*0.4), 'LifeSquare'] = (data['Square']*.9-df['KitchenSquare']-4)
    df.loc[((df['LifeSquare'] < 5) | (df['LifeSquare'] > df['Square'])), 'LifeSquare'] = (data['Square']*.8-4)
    
    #df.loc[df['Square'] < df['LifeSquare']*11, 'Square'] = df['LifeSquare']
    
    #df.loc[df['LifeSquare'] > 14, 'LifeSquare'] = df['Square']*0.6
    # По санПин в однушке жилая комната не меньше 14 кв.м.
    df.loc[df['LifeSquare'] < 14, 'LifeSquare'] = df['Square']*0.6
    df.loc[df['LifeSquare'] < 14, 'LifeSquare'] = 14.0

# %%
#Идея - средняя по району,  а не городу
def clean_Healthcare_1(df):
    df.loc[data['Healthcare_1'].isnull(), 'Healthcare_1'] = df["Healthcare_1"].mean()

# %%
def prepare_floor(df):
    df.loc[(df['HouseFloor']==0), 'HouseFloor'] = df['Floor'] +2
    df.loc[(df['HouseFloor']==1)&(df['Floor']>1), 'HouseFloor'] = df['Floor'] +2
    #df.loc[(df['HouseFloor']<df['Floor']), 'HouseFloor'] = df['Floor'] +2
    
    #Предположим, что местами этаж и этаж дома иногда переставлены. Поменяем их.
    df['HouseFloor2'] = df['HouseFloor']
    df.loc[(df['Floor'] > df['HouseFloor']), 'HouseFloor'] = df['Floor']
    df.loc[(df['Floor'] > df['HouseFloor2']), 'Floor'] = df['HouseFloor2']
    #df.loc[df['Floor'] > (df['HouseFloor']), df['HouseFloor']] 
    #df.loc[df['Floor'] > (df['HouseFloor'], [df['HouseFloor'], df['Floor']] = df['Floor'], df['HouseFloor']
                          
    # Разделим этажи на 3 категории: первый этаж, последний и остальные
    df['Floor_Categ'] = 3822
    df.loc[df['Floor'] == 1, 'Floor_Categ'] = 3452
    #df.loc[df['Floor'] == df['HouseFloor'], 'Floor_Categ'] = 1
    #df.loc[df['HouseFloor'] < df['Floor'], 'HouseFloor'] = df['Floor'] * 2 -1 
    df.loc[(df['HouseFloor'] > 70), 'HouseFloor'] = 70

# %%
#Комнаты бывают разные по площади. Присвоим категории комнатам, в зависимсоти от площади. 
#Для группировки в дальнейшем вместо комнат. 
def add_sq_categ_train(df):
    df['Sq_Categ'] =0
    df.loc[(data['Rooms']==1.0)&(df['Square']<32)&(df['Square']>=18) , ['Sq_Categ']] = 1
    df.loc[(data['Rooms']<3.0)&(df['Square']<50)&(df['Square']>=32) , ['Sq_Categ']] = 2
    df.loc[(data['Rooms']<5.0)&(df['Square']<80)&(df['Square']>=50) , ['Sq_Categ']] = 3
    df.loc[(df['Square']>=80) &(df['Square']<300), ['Sq_Categ']] = 4
    df.loc[(df['Price']/df['Square']>20000)|(df['Price']/df['Square']<900) , ['Sq_Categ']] = 0

#add_sq_categ(data)

# %%
def add_sq_categ_valid(df):
    df['Sq_Categ'] =0
    df.loc[(df['Square']<32) , ['Sq_Categ']] = 1
    df.loc[(df['Square']<50)&(df['Square']>=32) , ['Sq_Categ']] = 2
    df.loc[(df['Square']<80)&(df['Square']>=50) , ['Sq_Categ']] = 3
    df.loc[(df['Square']<300), ['Sq_Categ']] = 4

# %%
def prepare_square_train(df):
           
    #df.loc[(df['Square'] < df['LifeSquare']), 'Square'] = df['LifeSquare']*1.1 +df['KitchenSquare']+4.0 
    #Строки с 'm2_cost' на деле будут чистить только файл для обучения
    df.loc[(df['Square'] < 9) & (df['m2_cost'] >30000), 'Square'] = df['Square']*20
    df.loc[(df['Square'] < 15) & (df['m2_cost'] >15000), 'Square'] = df['Square']*10
    df.loc[(df['Square'] < 20) & (df['m2_cost'] >15000), 'Square'] = df['Square']*2
    df.loc[(df['Square'] > 200) & (df['m2_cost'] <1000), 'Square'] = df['Square']/10
    df.loc[(df['Rooms'] >1) & (df['Square']<20), 'Square'] = df['Square']+10
    #df.loc[(df['Square'] < 15) & (df['Rooms'] ==1.0), 'Square'] = 25.0
    #df.loc[(df['Square'] < 20) & (df['Rooms'] ==2.0), 'Square'] = 55.0
    #df.loc[(df['Square'] < 25)&(df['Rooms'] ==3.0), 'Square'] = 70.0
    #df.loc[(df['Square'] < 30)&(df['Rooms'] >3.0), 'Square'] = 100.0
    df.loc[(df['Square'] < 15), 'Square'] = 25.0
    df.loc[df['LifeSquare'] > df['Square'], 'LifeSquare'] = df['Square']*0.6

# %%
def prepare_square(df):
           
    #df.loc[(df['Square'] < df['LifeSquare']), 'Square'] = df['LifeSquare']*1.1 +df['KitchenSquare']+4.0 
    #Строки с 'm2_cost' на деле будут чистить только файл для обучения
    df.loc[(df['Square'] < 15) & (df['Rooms'] ==1.0 ), 'Square'] = 25
    df.loc[(df['Square'] < 30) & (df['Rooms'] ==2.0), 'Square'] = 45
    df.loc[(df['Square'] < 35) & (df['Rooms'] ==3.0), 'Square'] = 60
    df.loc[(df['Square'] > 1000), 'Square'] = df['Square']/10
    #df.loc[(df['Rooms'] >1) & (df['Square']<20), 'Square'] = df['Square']+10
    #df.loc[(df['Square'] < 15) & (df['Rooms'] ==1.0), 'Square'] = 25.0
    #df.loc[(df['Square'] < 20) & (df['Rooms'] ==2.0), 'Square'] = 55.0
    #df.loc[(df['Square'] < 25)&(df['Rooms'] ==3.0), 'Square'] = 70.0
    #df.loc[(df['Square'] < 30)&(df['Rooms'] >3.0), 'Square'] = 100.0
    #df.loc[(df['Square'] < 15), 'Square'] = 25.0
    df.loc[df['LifeSquare'] > df['Square'], 'LifeSquare'] = df['Square']*0.6

# %%
def prepare_letters(df):
    df['Shops_21'] = 1
    df.loc[df['Shops_2'] == 'A', 'Shops_21'] = 0
    df['Ecology_31'] = 1
    df.loc[df['Ecology_3'] == 'A', 'Ecology_31'] = 0
    df['Ecology_21'] = 1
    df.loc[df['Ecology_2'] == 'A', 'Ecology_21'] = 0
    #df['Ecology_21'] = df['Ecology_2'].map({'B': '1', 'A': '0'})
    #df['Ecology_31'] = df['Ecology_3'].map({'B': '1', 'A': '0'})
    #df['Shops_21'] = df['Shops_2'].map({'B': '1', 'A': '0'})

# %%
def prepare_data(df, mean_year=mean_year):
    add_sq_categ_train(df)
    clean_rooms(df)
    clean_life_square(df)
    #df['m2_cost'] = df['Price']/df['Square']
    clean_year(df, mean_year)
    clean_kitchen(df)
    prepare_life_square(df)
    prepare_square(df)
     
    clean_Healthcare_1(df)
    prepare_floor(df)
    prepare_letters(df)
    #df['m2_cost'] = df['Price']/df['Square']

# %%
prepare_data(train)

# %%
mean_m2_cost = train.groupby(['DistrictId', 'Sq_Categ'], as_index=False)[['Price', 'Square']].sum()
mean_m2_cost['mean_m2_cost'] = mean_m2_cost['Price']/mean_m2_cost['Square']
#mean_m2_cost.rename(columns={'mean_m2_cost':'mean_m2_cos2'})
mean_m2_cost= mean_m2_cost.drop('Square', axis=1)
mean_m2_cost= mean_m2_cost.drop('Price', axis=1)
#mean_m2_cost= mean_m2_cost.drop(mean_m2_cost.loc[mean_m2_cost['Sq_Categ'] ==0]], axis=0)
mean_m2_cost.head()
# Out:
#    DistrictId  Sq_Categ  mean_m2_cost
# 0           0         1   5194.954719
# 1           0         2   3381.440960
# 2           0         3   3786.692173
# 3           0         4   2922.539262
# 4           1         0   1865.555669

# %%
mean_m2_cost2 = train.groupby(['DistrictId'], as_index=False)[['Price', 'Square']].sum()
mean_m2_cost2['mean_m2_cost2'] = mean_m2_cost2['Price']/mean_m2_cost2['Square']
mean_m2_cost2= mean_m2_cost2.drop('Square', axis=1)
mean_m2_cost2= mean_m2_cost2.drop('Price', axis=1)
#mean_m2_cost= mean_m2_cost.drop(mean_m2_cost.loc[mean_m2_cost['Sq_Categ'] ==0]], axis=0)
mean_m2_cost2.head()
# Out:
#    DistrictId  mean_m2_cost2
# 0           0    3464.590320
# 1           1    3158.384634
# 2           2    4561.471139
# 3           3    3468.171269
# 4           4    4017.311054

# %%
sum_price_all = train.loc[train['Sq_Categ'] > 0, 'Price'].sum()
sq_price_all = train.loc[train['Sq_Categ'] > 0, 'Square'].sum()
train.loc[(train['Id']==3766)]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 5753  3766          62    3.0  127.41756   76.450536            0.0    9.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 5753        11.0     1977.0   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 5753       629         1   1133.876167            0        0       A
#
#               Price  Sq_Categ  HouseFloor2  Floor_Categ  Shops_21  Ecology_31  \
# 5753  282877.332154         4         11.0         3822         0           1
#
#       Ecology_21
# 5753           1

# %%
plt.scatter(train['KitchenSquare'], train['Price'])
plt.axis([-10, 50,0,600000])
plt.show()
# Есть небольшая зависимость, но она веротяно больше косвенная( от общей площади). И много неточных данных

# %%
train.loc[train['LifeSquare'] >200.0 , :]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4262    28           9    2.0  604.705972  362.823583            9.0   17.0
# 4690  2307         102    1.0  409.425181  327.540145           10.0    4.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4262        18.0     1977.0   0.161532         B         B        25
# 4690         4.0     2016.0   0.238617         B         B        26
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4262      5648         1          30.0            2        4       B
# 4690      3889         6         705.0            3        6       B
#
#               Price  Sq_Categ  HouseFloor2  Floor_Categ  Shops_21  Ecology_31  \
# 4262  187717.242538         0         18.0         3822         1           1
# 4690   90470.430830         0          4.0         3822         1           1
#
#       Ecology_21
# 4262           1
# 4690           1

# %%
#plt.scatter(train['Square'], train['m2_cost'])
#plt.axis([0, 50,0,25000])
#plt.xlabel('Площадь')
#plt.ylabel('Цена М2')
#plt.show()

# %%
train.loc[train['Id'] ==12676 , :]
# Out:
#          Id  DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  \
# 4739  12676          81    3.0    60.0        14.0            7.0    4.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4739         5.0     1960.0   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4739      4756        16        2857.0            5        8       B
#
#              Price  Sq_Categ  HouseFloor2  Floor_Categ  Shops_21  Ecology_31  \
# 4739  78388.806186         0          5.0         3822         1           1
#
#       Ecology_21
# 4739           1

# %%
train.loc[(train['Rooms'] >1) & (train['Square']<25), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Sq_Categ, HouseFloor2, Floor_Categ, Shops_21, Ecology_31, Ecology_21]
# Index: []

# %%
plt.scatter(train['Square'], train['Rooms'])
#plt.axis([0, 1000,0,700000])
plt.show()

# %%
#plt.scatter(train['Ecology_31'], train['m2_cost'])
#plt.axis([0, 1000,0,700000])
#plt.show()
#более дорогие квартиры только в экологии со значением 1

# %%
#plt.scatter(train['Square'], train['m2_cost'])
#plt.axis([0, 1000,0,700000])
#plt.show()

# %%
train.loc[(train['Floor_Categ'] !=2)&(train['Floor_Categ'] !=1)&(train['Floor_Categ'] !=0), :].head()
train.loc[train['Ecology_3'] == 'A', :].count()
train.loc[train['Ecology_2'] == 'B', :].count()
train.head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9069  14604          23    1.0   41.681380   22.796166            8.0   14.0
# 2603   5621          23    3.0  163.495333  161.504222           12.0    3.0
# 7738    235          87    1.0   39.710131   19.538663            8.0    4.0
# 1579  16258          48    3.0   96.056784   73.451106            9.0   15.0
# 5058  10773          77    3.0   79.195825   44.421062           10.0   16.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9069        17.0     2015.0   0.075779         B         B         6
# 2603         5.0     1977.0   0.014073         B         B         2
# 7738        17.0     1986.0   0.100456         B         B        43
# 1579        17.0     2017.0   0.041125         B         B        46
# 5058        17.0     1984.0   0.298205         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9069      1437         3   1133.876167            0        2       B
# 2603       475         0   1133.876167            0        0       B
# 7738      7227         0   1133.876167            1        6       A
# 1579      9515         5   1133.876167            1       10       B
# 5058      4048         3   1133.876167            1        3       B
#
#               Price  Sq_Categ  HouseFloor2  Floor_Categ  Shops_21  Ecology_31  \
# 9069   88504.384965         2         17.0         3822         1           1
# 2603  207007.956663         4          3.0         3822         1           1
# 7738  182126.280899         2         17.0         3822         0           1
# 1579  524365.550705         4         17.0         3822         1           1
# 5058  322048.433990         3         17.0         3822         1           1
#
#       Ecology_21
# 9069           1
# 2603           1
# 7738           1
# 1579           1
# 5058           1

# %%
#train.loc[train['m2_cost'] >20000.0 , :]

# %%
train.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   7000.000000  7000.000000  7000.000000  7000.000000  7000.000000
# mean    8386.061714    50.560857     1.885000    56.371858    35.877296
# std     4864.141324    43.744178     0.808268    20.434849    15.672781
# min        0.000000     0.000000     1.000000    16.117154    14.000000
# 25%     4176.500000    19.000000     1.000000    41.774881    24.176179
# 50%     8398.500000    37.000000     2.000000    52.671446    33.054255
# 75%    12562.000000    75.000000     2.000000    65.983195    44.152305
# max    16796.000000   209.000000     5.000000   604.705972   362.823583
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    7000.000000  7000.000000  7000.000000  7000.000000  7000.000000
# mean        7.765282     8.363714    13.614000  1984.919714     0.117840
# std         3.081127     5.150069     5.889357    18.310614     0.118599
# min         0.000000     1.000000     1.000000  1912.000000     0.000000
# 25%         6.000000     4.000000     9.000000  1974.000000     0.017647
# 50%         9.000000     7.000000    14.000000  1977.000000     0.075424
# 75%         9.000000    12.000000    17.000000  2001.000000     0.194489
# max        43.000000    42.000000    70.000000  2020.000000     0.521867
#
#           Social_1      Social_2     Social_3  Healthcare_1  Helthcare_2  \
# count  7000.000000   7000.000000  7000.000000   7000.000000  7000.000000
# mean     24.767571   5364.425714     8.044571   1133.876167     1.313143
# std      17.583889   4011.768297    23.869975    734.499360     1.488326
# min       0.000000    168.000000     0.000000     30.000000     0.000000
# 25%       6.000000   1564.000000     0.000000    825.000000     0.000000
# 50%      25.000000   5285.000000     2.000000   1133.876167     1.000000
# 75%      36.000000   7227.000000     5.000000   1133.876167     2.000000
# max      74.000000  19083.000000   141.000000   4849.000000     6.000000
#
#            Shops_1          Price     Sq_Categ  HouseFloor2  Floor_Categ  \
# count  7000.000000    7000.000000  7000.000000  7000.000000  7000.000000
# mean      4.260571  214449.167390     2.616286    13.471429  3813.648571
# std       4.825024   92924.798790     0.723865     6.147800    54.961020
# min       0.000000   59174.778028     0.000000     1.000000  3452.000000
# 25%       1.000000  154599.240157     2.000000     9.000000  3822.000000
# 50%       3.000000  192290.039215     3.000000    14.000000  3822.000000
# 75%       6.000000  249080.956886     3.000000    17.000000  3822.000000
# max      23.000000  627525.072788     4.000000   117.000000  3822.000000
#
#           Shops_21   Ecology_31   Ecology_21
# count  7000.000000  7000.000000  7000.000000
# mean      0.916571     0.971143     0.990857
# std       0.276549     0.167417     0.095187
# min       0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     1.000000
# 50%       1.000000     1.000000     1.000000
# 75%       1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000

# %%
coef_sq1 = (train.loc[(data['Square'] > 13)&(train['Square'] < 28), 'Price']).sum()/(train.loc[(data['Square'] > 13)&(train['Square'] < 30), 'Square'].sum())
coef_sq2 = (train.loc[(data['Square'] >= 30)&(train['Square'] < 50), 'Price']).sum()/(train.loc[(data['Square'] >= 30)&(train['Square'] < 50), 'Square'].sum())
coef_sq3 = (train.loc[(data['Square'] >= 50)&(train['Square'] < 75), 'Price']).sum()/(train.loc[(data['Square'] >= 50)&(train['Square'] < 75), 'Square'].sum())
coef_sq4 = (train.loc[(data['Square'] >= 75)&(train['Square'] < 111), 'Price']).sum()/(train.loc[(data['Square'] >= 75)&(train['Square'] < 111), 'Square'].sum())
coef_sq5 = (train.loc[(data['Square'] >= 111), 'Price']).sum()/(train.loc[(data['Square'] >= 111), 'Square'].sum())
coef_sq2
# Out:
# 4073.23756562814

# %%
#введем цену за метр для квартир разной площади, вместо количства комнат
(train.loc[train['Floor'] > 1, 'Price'].sum()/train.loc[train['Floor'] > 1, 'Square'].sum())
# Out:
# 3812.091462445238

# %%
train_corr = train.corr()
high_corr = train_corr.drop('Price', axis=0)
high_corr = high_corr[high_corr['Price']**2>0.01]
high_corr.axes[0].tolist()
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'Social_1',
#  'Social_2',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Sq_Categ',
#  'HouseFloor2']

# %%
train.groupby('DistrictId', as_index=False)[['Price']].mean().sort_values('Price', ascending=False).head()
# Out:
#      DistrictId          Price
# 189         190  516137.070651
# 198         202  502085.860162
# 194         195  482791.138606
# 180         181  477217.801361
# 181         182  471000.007453

# %%
'''
mean_price = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price']].sum().\
    rename(columns={'Price':'sum_price'})
mean_price['sum_sq'] = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Square']].sum()['Square']
mean_price['meter_cost'] = mean_price['sum_price']/mean_price['sum_sq']
mean_price = mean_price.drop(['sum_price', 'sum_sq'], axis=1)
'''
mean_price = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price']].mean().\
    rename(columns={'Price':'mean_price'})
mean_price.head()
# Out:
#    DistrictId  Rooms     mean_price
# 0           0    1.0  145789.889600
# 1           0    2.0  198451.332808
# 2           0    3.0  291670.749162
# 3           1    1.0  146748.710984
# 4           1    2.0  198775.648383

# %%
'''
mean_price2 = train.groupby('DistrictId', as_index=False)[['Price']].sum().\
    rename(columns={'Price':'sum_price'})
mean_price2['sum_sq'] = train.groupby(['DistrictId'], as_index=False)[['Square']].sum()['Square']
mean_price2['meter_cost2'] = mean_price2['sum_price']/mean_price2['sum_sq']
mean_price2 = mean_price2.drop(['sum_price', 'sum_sq'], axis=1)
mean_price2.head()
'''
mean_price2 = train.groupby('Rooms', as_index=False)[['Price']].mean().\
    rename(columns={'Price':'mean_price2'})
mean_price2.head()
# Out:
#    Rooms    mean_price2
# 0    1.0  160108.230541
# 1    2.0  215330.295609
# 2    3.0  290867.452543
# 3    4.0  384647.855311
# 4    5.0  432207.994987

# %%
print(type(train['DistrictId']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
mean_price_all = train['Price'].mean()
mean_price_all
# Out:
# 214449.1673897029

# %%
'''
def add_mean_price(df, mean_price=mean_price, mean_price2=mean_price2):
    global mean_price_all
    df = pd.merge(df, mean_price2,  on='DistrictId', how='left' )
    df['meter_cost2'] = df['meter_cost2'].fillna(mean_price_all)
    df = pd.merge(df, mean_price, on=['DistrictId', 'Rooms'], how='left')
    df['meter_cost'] = df['meter_cost'].fillna(df['meter_cost2'])
    df = df.drop('meter_cost2', axis=1)
    return df

'''
# Out:
# "\ndef add_mean_price(df, mean_price=mean_price, mean_price2=mean_price2):\n    global mean_price_all\n    df = pd.merge(df, mean_price2,  on='DistrictId', how='left' )\n    df['meter_cost2'] = df['meter_cost2'].fillna(mean_price_all)\n    df = pd.merge(df, mean_price, on=['DistrictId', 'Rooms'], how='left')\n    df['meter_cost'] = df['meter_cost'].fillna(df['meter_cost2'])\n    df = df.drop('meter_cost2', axis=1)\n    return df\n\n"

# %%
def add_mean_price(df, mean_price=mean_price, mean_price2=mean_price2):
    global mean_price_all
    df = pd.merge(df, mean_price2, on='Rooms', how='left')
    df['mean_price2'] = df['mean_price2'].fillna(mean_price_all)
    df = pd.merge(df, mean_price, on=['DistrictId', 'Rooms'], how='left')
    df['mean_price'] = df['mean_price'].fillna(df['mean_price2'])
    df = df.drop('mean_price2', axis=1)
    return df


def add_mean_cost(df, mean_m2_cost=mean_m2_cost, mean_m2_cost2=mean_m2_cost2):
    global mean_cost_all
     
    df = pd.merge(df, mean_m2_cost2, on='DistrictId', how='left')
    #df['mean_m2_cost2'] = df['mean_m2_cost2'].fillna(mean_price_all)
    df = pd.merge(df, mean_price, on=['DistrictId', 'Sq_Categ'], how='left')
    df['mean_m2_cost'] = df['mean_m2_cost'].fillna(df['mean_m2_cost2'])
    #df = df.drop('m2_cost2', axis=1)
    return df

# %%
#train = add_mean_price(train)
train = add_mean_cost(train)
train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1162-f7c5d379e803> in <module>
#       1 #train = add_mean_price(train)
# ----> 2 train = add_mean_cost(train)
#       3 train.head()
#
# <ipython-input-1161-753a7211c125> in add_mean_cost(df, mean_m2_cost, mean_m2_cost2)
#      15     df = pd.merge(df, mean_m2_cost2, on='DistrictId', how='left')
#      16     #df['mean_m2_cost2'] = df['mean_m2_cost2'].fillna(mean_price_all)
# ---> 17     df = pd.merge(df, mean_price, on=['DistrictId', 'Sq_Categ'], how='left')
#      18     df['mean_m2_cost'] = df['mean_m2_cost'].fillna(df['mean_m2_cost2'])
#      19     #df = df.drop('m2_cost2', axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# --> 551          self.join_names) = self._get_merge_keys()
#     552
#     553         # validate the merge keys dtypes. We may need to coerce
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     855                             right_keys.append(
#     856                                 right._get_label_or_level_values(
# --> 857                                     rk, stacklevel=stacklevel))
#     858                         else:
#     859                             # work-around for merge_asof(right_index=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'Sq_Categ'

# %%
train.head()

# %%
valid.head()

# %%
train.describe()

# %%
#valid = add_mean_price(valid)
prepare_data(valid)
valid = add_mean_cost(valid)
#prepare_data(valid)
valid.head()

# %% [markdown]
# #### Model

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.metrics import r2_score as r2
from sklearn.model_selection import GridSearchCV

# %%
feats = ['Square', 'LifeSquare','Rooms', 'HouseYear', 'm2_cost', 'Social_1','Helthcare_2', 'Ecology_31', 'Floor', 'HouseFloor']

# %%
parameters = [{'n_estimators': [ 300 ], 
               'min_samples_split': [12],
               'random_state': [10000],
               'min_samples_leaf': [ 4, 8],
               'max_depth': [15]}]

# %%
model = GridSearchCV(estimator=RFR( warm_start = True), 
                   param_grid=parameters,
                   scoring='r2',
                   cv=3)
model = RFR(max_depth=12, random_state=42)

# %%
model.fit(train.loc[:, feats], train['Price'])
#model.best_params_

# %%
y_pred_train = model.predict(train.loc[:, feats])
#model.best_params_

# %%
r2(train['Price'], y_pred_train)

# %%
y_pred_valid = model.predict(valid.loc[:, feats])

# %%
r2(valid['Price'], y_pred_valid)

# %%
RFR?

# %% [markdown]
# #### Test

# %%
test = pd.read_csv('input/test.csv')

# %%
test = add_mean_price(test)

# %%
prepare_data(test)

# %%
test['Price'] = model.predict(test.loc[:, feats])

# %%
test.head()

# %%
test.loc[:, ['Id', 'Price']].to_csv('SShirkin_predictions.csv', index=None)
